# %% [markdown]
# ### Machine Learning Pipeline
# >Data collection
#
# >Data preparation (data cleaning)
#
# >spliting the dataset (Vertically and horizontally)
#
# >Model Building (choose related model based on data)
#
# >Evaluating model...

# %% [markdown]
# ### Model building
# >Import Library
#
# >Import(load) dataset
#
# >Data cleaning & analysis
#
# >Split data into training and testing set
#
# >Choose model (i.e algorithim)..
#
# >Train the model(fit the moodel)..
#
# >test the model..
#
# >Evaluate model..

# %%
### importing libraries
import pandas as pd
import numpy as np

# %%
### loading dataset
df=pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
##if any duplicates are found, we can remove them using the drop_duplicates() method.
df.drop_duplicates()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
### deal with null values
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# no any null values

# %%
! pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
## remove unwanted columns

## remove unwanted columns
df.drop(columns=['Unnamed: 0'], inplace=True, errors='ignore')

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.plot()
# Out:
# []

# %% [markdown]
# ### spliting dataset as training and testing test

# %%
! pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(df['YearsExperience'],df['Salary'],test_size=0.2,random_state=0)
# Out:
# [27     9.7
#  11     4.1
#  17     5.4
#  22     8.0
#  5      3.0
#  16     5.2
#  8      3.3
#  14     4.6
#  23     8.3
#  20     6.9
#  1      1.4
#  29    10.6
#  6      3.1
#  4      2.3
#  18     6.0
#  19     6.1
#  9      3.8
#  7      3.3
#  25     9.1
#  3      2.1
#  0      1.2
#  21     7.2
#  15     5.0
#  12     4.1
#  Name: YearsExperience, dtype: float64,
#  2      1.6
#  28    10.4
#  13     4.2
#  10     4.0
#  26     9.6
#  24     8.8
#  Name: YearsExperience, dtype: float64,
#  27    112636.0
#  11     55795.0
#  17     83089.0
#  22    101303.0
#  5      56643.0
#  16     66030.0
#  8      64446.0
#  14     61112.0
#  23    113813.0
#  20     91739.0
#  1      46206.0
#  29    121873.0
#  6      60151.0
#  4      39892.0
#  18     81364.0
#  19     93941.0
#  9      57190.0
#  7      54446.0
#  25    105583.0
#  3      43526.0
#  0      39344.0
#  21     98274.0
#  15     67939.0
#  12     56958.0
#  Name: Salary, dtype: float64,
#  2      37732.0
# ...

# %%
### vertically dividing the dataset as input and output
x=df.iloc[:,0]
y=df.iloc[:,1]

# %%
### splitting the dataset into training and testing sets
from sklearn.model_selection import train_test_split

# %%
train_test_split(x,y,test_size=0.2,random_state=0)
# Out:
# [27     9.7
#  11     4.1
#  17     5.4
#  22     8.0
#  5      3.0
#  16     5.2
#  8      3.3
#  14     4.6
#  23     8.3
#  20     6.9
#  1      1.4
#  29    10.6
#  6      3.1
#  4      2.3
#  18     6.0
#  19     6.1
#  9      3.8
#  7      3.3
#  25     9.1
#  3      2.1
#  0      1.2
#  21     7.2
#  15     5.0
#  12     4.1
#  Name: YearsExperience, dtype: float64,
#  2      1.6
#  28    10.4
#  13     4.2
#  10     4.0
#  26     9.6
#  24     8.8
#  Name: YearsExperience, dtype: float64,
#  27    112636.0
#  11     55795.0
#  17     83089.0
#  22    101303.0
#  5      56643.0
#  16     66030.0
#  8      64446.0
#  14     61112.0
#  23    113813.0
#  20     91739.0
#  1      46206.0
#  29    121873.0
#  6      60151.0
#  4      39892.0
#  18     81364.0
#  19     93941.0
#  9      57190.0
#  7      54446.0
#  25    105583.0
#  3      43526.0
#  0      39344.0
#  21     98274.0
#  15     67939.0
#  12     56958.0
#  Name: Salary, dtype: float64,
#  2      37732.0
# ...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# #### Import Model

# %%
from sklearn.linear_model import LinearRegression

# %%
### training the model
lr=LinearRegression()
lr.fit(xtrain.values.reshape(-1, 1), ytrain)
# Out:
# LinearRegression()

# %%
xtest.values
# Out:
# array([ 1.6, 10.4,  4.2,  4. ,  9.6,  8.8])

# %%
## predicting
model_predict=lr.predict(xtest.values.reshape(-1, 1))

# %%
len(xtest)
# Out:
# 6

# %%
ytest.values
# Out:
# array([ 37732., 122392.,  57082.,  63219., 116970., 109432.])

# %%
### evaluating the model
from sklearn.metrics import mean_absolute_error,root_mean_squared_error,r2_score

root_mean_squared_error(ytest,model_predict)
r2_score(ytest,model_predict)
# Out:
# 0.988169515729126

# %%
r2_score(ytest,model_predict)*100
# Out:
# 98.8169515729126
